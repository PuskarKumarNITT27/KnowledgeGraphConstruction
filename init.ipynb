# %%
from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(
    model="gemini-3.1-flash-lite-preview",
    temperature=0
)

# %%
result = llm.invoke('what is the capital of india')
print(result.content[0]['text'])
# Out:
# The capital of India is **New Delhi**.

# %%
from langchain_neo4j import Neo4jGraph

try:
    print("🔄 Connecting to local Neo4j...")

    graph = Neo4jGraph(
        url="bolt://localhost:7687",   # ✅ Always 7687 for Python, NOT 7474
        username="neo4j",
        password="Nitt@2026",      # 👈 password you set during Neo4j Desktop setup
    )

    result = graph.query("RETURN 'Connected!' AS message")
    print(f"✅ {result[0]['message']}")

    print("\n🎉 Local Neo4j is ready!")

except Exception as e:
    print(f"❌ Failed: {e}")
# Out:
# 🔄 Connecting to local Neo4j...
# ✅ Connected!
#
# 🎉 Local Neo4j is ready!
